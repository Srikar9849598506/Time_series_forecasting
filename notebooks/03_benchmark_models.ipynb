# %% [markdown]
# # 03 - Benchmark Models
#
# Runs the benchmark stage and produces mean, naive, daily seasonal-naive, weekly seasonal-naive and drift forecasts plus MAE/RMSE/MASE/Bias.

# %%
import subprocess, sys
subprocess.run([sys.executable, '../scripts/run_benchmarks.py'], check=True)

# %% [markdown]
# # 05 - Feature-Based Model (XGBoost)
#
# Runs the leakage-safe recursive XGBoost feature model using time, lag/rolling, indoor and outdoor covariates. Future sensor/weather values are treated as a conditional forecast.

# %%
import subprocess, sys
subprocess.run([sys.executable, '../scripts/run_feature_model.py'], check=True)

# %% [markdown]
# # 07 - Final Model Comparison
#
# Combines every forecast on the same 24-hour evaluation window and produces the final metrics table and forecast plots.

# %%
import subprocess, sys
subprocess.run([sys.executable, '../scripts/run_final_comparison.py'], check=True)

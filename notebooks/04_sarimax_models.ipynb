# %% [markdown]
# # 04 - SARIMA / SARIMAX Models
#
# Runs the required 147-order AIC search, fits target-only SARIMA and weather-exogenous SARIMAX, creates residual diagnostics and 95% confidence intervals.

# %%
import subprocess, sys
subprocess.run([sys.executable, '../scripts/run_sarimax.py'], check=True)

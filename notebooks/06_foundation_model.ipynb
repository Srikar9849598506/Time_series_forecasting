# %% [markdown]
# # 06 - Foundation Model (Chronos)
#
# Runs the real zero-shot Chronos foundation model. No fallback is used; preflight must pass first.

# %%
import subprocess, sys
subprocess.run([sys.executable, '../scripts/run_foundation_model.py'], check=True)
